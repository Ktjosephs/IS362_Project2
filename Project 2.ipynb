# %% [markdown]
# ## Project 2
# ### By Kimesha Josephs

# %% [markdown]
# Import Pandas

# %%
import pandas as pd

# %% [markdown]
# Import source file.

# %%
file = "/Users/kimeshajosephs/Documents/GitHub/IS362_Project2/attendance.csv"
data = pd.read_csv(file, encoding='utf-8', header=None)
data.head()
# Out:
#                                                  0    \
# 0  Table 43. Average daily attendance (ADA) as a ...
# 1                                                NaN
# 2                                                NaN
# 3                                                  1
# 4                             United States ........
#
#                                                  1       2    \
# 0                                                NaN     NaN
# 1  Total elementary, secondary, and combined elem...     NaN
# 2                       ADA as percent of enrollment     NaN
# 3                                                  2     NaN
# 4                                               93.1  (0.22)
#
#                            3       4                            5      6    \
# 0                          NaN     NaN                          NaN    NaN
# 1                          NaN     NaN                          NaN    NaN
# ...

# %% [markdown]
# Drop unnecessary columns

# %%
data.drop(data.columns[17:], axis=1, inplace=True)
data.head()
# Out:
#                                                   0   \
# 0  Table 43. Average daily attendance (ADA) as a ...
# 1                                                NaN
# 2                                                NaN
# 3                                                  1
# 4                             United States ........
#
#                                                   1       2   \
# 0                                                NaN     NaN
# 1  Total elementary, secondary, and combined elem...     NaN
# 2                       ADA as percent of enrollment     NaN
# 3                                                  2     NaN
# 4                                               93.1  (0.22)
#
#                             3       4                            5      6   \
# 0                          NaN     NaN                          NaN    NaN
# 1                          NaN     NaN                          NaN    NaN
# ...

# %% [markdown]
# Drop unnecessary rows.

# %%
data.drop(data.index[[0,1,2,3]], inplace=True)
data.head()
# Out:
#                           0     1       2    3       4    5      6      7   \
# 4     United States ........  93.1  (0.22)  6.6  (0.02)  180  (0.1)  1,193
# 5  Alabama .................  93.8  (1.24)  7.0  (0.07)  180  (0.8)  1,267
# 6  Alaska ..................  89.9  (1.22)  6.5  (0.05)  180  (3.4)  1,163
# 7  Arizona .................  89.0  (2.95)  6.4  (0.09)  181  (1.7)  1,159
# 8  Arkansas ................  91.8  (1.35)  6.9  (0.06)  179  (0.2)  1,229
#
#        8     9       10   11      12    13      14   15      16
# 4   (3.1)  94.0  (0.27)  6.7  (0.02)  91.1  (0.43)  6.6  (0.04)
# 5  (12.3)  93.8  (1.84)  7.0  (0.08)  94.6  (0.38)  7.1  (0.17)
# 6  (22.9)  91.3  (1.56)  6.5  (0.05)  93.2  (1.57)  6.2  (0.15)
# 7  (14.4)  88.9  (3.91)  6.4  (0.10)  89.0  (3.22)  6.4  (0.25)
# 8  (10.7)  92.1  (2.09)  6.9  (0.08)  90.8  (2.23)  6.8  (0.10)

# %%
file = "/Users/kimeshajosephs/Documents/GitHub/IS362_Project2/PolarBear_resting_metabolic_rate_data_2017.csv"
data = pd.read_csv(file, encoding='utf-8')
data.head()
# Out:
#    Body_Mass  Air_Temperature  Relative_Humidity  Pressure  Flow_Rate  \
# 0        264             15.9               99.0     758.2        450
# 1        264             16.4               99.9     758.5        500
# 2        264             16.3               86.3     759.4        500
# 3        264             16.6               97.1     760.8        500
# 4        264             15.9               99.9     760.1        500
#
#    FI_O2_Start  FI_O2_End    FEO2  Unnamed: 8  Unnamed: 9  Unnamed: 10
# 0       20.946     20.912  20.683         NaN         NaN          NaN
# 1       20.951     20.951  20.709         NaN         NaN          NaN
# 2       20.952     20.962  20.710         NaN         NaN          NaN
# 3       20.944     20.954  20.700         NaN         NaN          NaN
# 4       20.948     20.946  20.740         NaN         NaN          NaN

# %%
data.drop(data.columns[8:], axis=1, inplace=True)
data.head()
# Out:
#    Body_Mass  Air_Temperature  Relative_Humidity  Pressure  Flow_Rate  \
# 0        264             15.9               99.0     758.2        450
# 1        264             16.4               99.9     758.5        500
# 2        264             16.3               86.3     759.4        500
# 3        264             16.6               97.1     760.8        500
# 4        264             15.9               99.9     760.1        500
#
#    FI_O2_Start  FI_O2_End    FEO2
# 0       20.946     20.912  20.683
# 1       20.951     20.951  20.709
# 2       20.952     20.962  20.710
# 3       20.944     20.954  20.700
# 4       20.948     20.946  20.740

# %%
file = "/Users/kimeshajosephs/Documents/GitHub/IS362_Project2/Table_4_January_to_June_2017_Offenses_Reported_to_Law_Enforcement_by_State_by_City_100,000_and_Over_in_Population.csv"
data = pd.read_csv(file, encoding='utf-8')
data.head()
# Out:
#                                            Table 4  Unnamed: 1  Unnamed: 2  \
# 0                        January to June 2016–2017         NaN         NaN
# 1            Offenses Reported to Law Enforcement          NaN         NaN
# 2  by State by City 100,000 and over in population         NaN         NaN
# 3                                            State        City         NaN
# 4                                          ALABAMA  BIRMINGHAM      2016.0
#
#     Unnamed: 3      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0          NaN             NaN        NaN        NaN        NaN
# 1          NaN             NaN                   NaN        NaN
# 2          NaN             NaN        NaN        NaN        NaN
# 3  Population1  Violent\ncrime     Murder      Rape2    Robbery
# 4      212,549           1,732         44         75        460
#
#             Unnamed: 8       Unnamed: 9 Unnamed: 10      Unnamed: 11  \
# ...

# %%
data.drop(data.index[[0,1,2]], inplace=True)
data.head()
# Out:
#    Table 4  Unnamed: 1  Unnamed: 2   Unnamed: 3      Unnamed: 4 Unnamed: 5  \
# 3    State        City         NaN  Population1  Violent\ncrime     Murder
# 4  ALABAMA  BIRMINGHAM      2016.0      212,549           1,732         44
# 5      NaN         NaN      2017.0          NaN           1,829         42
# 6      NaN     MOBILE4      2016.0      249,921             793         18
# 7      NaN         NaN      2017.0          NaN             925         20
#
#   Unnamed: 6 Unnamed: 7           Unnamed: 8       Unnamed: 9 Unnamed: 10  \
# 3      Rape2    Robbery  Aggravated\nassault  Property\ncrime    Burglary
# 4         75        460                1,153            5,875       1,318
# 5         92        472                1,223            6,458       1,292
# 6         47        181                  547            5,169       1,100
# 7         53        235                  617            6,482       1,507
#
#        Unnamed: 11            Unnamed: 12 Unnamed: 13  Unnamed: 14  \
# ...

# %%
data.drop(data.columns[13:], axis=1, inplace=True)
data.head()
# Out:
#    Table 4  Unnamed: 1  Unnamed: 2   Unnamed: 3      Unnamed: 4 Unnamed: 5  \
# 3    State        City         NaN  Population1  Violent\ncrime     Murder
# 4  ALABAMA  BIRMINGHAM      2016.0      212,549           1,732         44
# 5      NaN         NaN      2017.0          NaN           1,829         42
# 6      NaN     MOBILE4      2016.0      249,921             793         18
# 7      NaN         NaN      2017.0          NaN             925         20
#
#   Unnamed: 6 Unnamed: 7           Unnamed: 8       Unnamed: 9 Unnamed: 10  \
# 3      Rape2    Robbery  Aggravated\nassault  Property\ncrime    Burglary
# 4         75        460                1,153            5,875       1,318
# 5         92        472                1,223            6,458       1,292
# 6         47        181                  547            5,169       1,100
# 7         53        235                  617            6,482       1,507
#
#        Unnamed: 11            Unnamed: 12
# ...

# %% [markdown]
# Turn the first row into the column header

# %%
data.rename(columns=data.iloc[0]).drop(data.index[0]).head(5)
# Out:
#      State        City     NaN Population1 Violent\ncrime Murder Rape2  \
# 4  ALABAMA  BIRMINGHAM  2016.0     212,549          1,732     44    75
# 5      NaN         NaN  2017.0         NaN          1,829     42    92
# 6      NaN     MOBILE4  2016.0     249,921            793     18    47
# 7      NaN         NaN  2017.0         NaN            925     20    53
# 8      NaN  MONTGOMERY  2016.0     199,565            563     18    42
#
#   Robbery Aggravated\nassault Property\ncrime Burglary Larceny-\ntheft  \
# 4     460               1,153           5,875    1,318           3,807
# 5     472               1,223           6,458    1,292           4,350
# 6     181                 547           5,169    1,100           3,724
# 7     235                 617           6,482    1,507           4,344
# 8     187                 316           4,229    1,043           2,790
#
#   Motor\nvehicle\ntheft
# 4                   750
# 5                   816
# 6                   345
# ...
